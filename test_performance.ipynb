# %%
parameters = [10, 20, 40, 80, 160, 320, 640, 1280, 2560, 5120, 10240, 20480, 40960, 81920, 163840, 327680, 655360, 1310720, 2621440, 5242880, 10485760, 20971520, 41943040, 83886080, 167772160, 335544320]
times = [0.034604, 0.001279, 0.000970, 0.000833, 0.000782, 0.000806, 0.001098, 0.001543, 0.001825, 0.004089, 0.006654, 0.013602, 0.017404, 0.085779, 0.055810, 0.105599, 0.202606, 0.435754, 0.839118, 1.696103, 3.227771, 6.633884, 13.215485, 26.148643, 56.838495, 116.494133]
memory = [0.074, 0.074, 0.079, 0.089, 0.111, 0.146, 0.178, 0.327, 0.716, 1.603, 3.295, 6.649, 13.462, 26.858, 53.886, 104.561, 209.727, 419.815, 847.288, 1697.792, 3383.296, 6802.432, 13635.584, 27382.784, 54825.984, 109853.696]
using Plots

# Time vs Parameters
plot(parameters, times, title = "Execute time vs simulation time", xlabel = "Simulation time", ylabel = "Execute time (Seconds)", label = "simulation time", legend = :topleft)
# save the image in Images folder
savefig("Images/Time_vs_Parameters.png")
# Memory vs Parameters
# Out:
# "/home/an/Workspace/Assignment3DecisionScience/Images/Time_vs_Parameters.png"

# %%
plot(parameters, memory, title = "Memory vs Parameters", xlabel = "Parameters", ylabel = "Memory (MB)", label = "Memory", legend = :topleft)

# %%
plot(parameters, times, title = "Time vs Parameters", xlabel = "Parameters", ylabel = "Time (Seconds)", label = "Time", legend = :topleft)

# Memory vs Parameters on a Log Scale

# %%
plot(parameters, memory, title = "Log Scale: Memory vs Parameters", xlabel = "Parameters", ylabel = "Memory (MB)", label = "Memory", xscale = :log10, yscale = :log10, legend = :topleft)

# %%
plot(parameters, memory, title = "Log Scale: Memory vs Parameters", xlabel = "Parameters", ylabel = "Memory (MB)", label = "Memory", xscale = :log10, yscale = :log10, legend = :topleft)
